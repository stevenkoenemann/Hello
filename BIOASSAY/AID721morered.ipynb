# %%
# using plaidml to connect to my eGPU
import os

os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

# %%
# read csv file into a pandas dataframe
import numpy as np
import pandas as pd

train = pd.read_csv('AID721morered_train.csv')
test = pd.read_csv('AID721morered_test.csv')

# %%
# Function for converting categorical label into a numerical one
def outcome_to_numeric(x):
    if x=='Inactive':
        return 0
    if x=='Active':
        return 1
    
# Apply function to label column
train['label'] = train['Outcome'].apply(outcome_to_numeric)
test['label'] = test['Outcome'].apply(outcome_to_numeric)

# Drop categorical column
train=train.drop('Outcome', axis=1)
test=test.drop('Outcome', axis=1)

# Split datasets into feature and label dataframes
x_train = train.drop('label', axis=1)
y_train = train['label']

x_test = test.drop('label', axis=1)
y_test = test['label']

from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
# %matplotlib inline

# Select best features for the label
model = ExtraTreesClassifier()
model.fit(x_train, y_train)

feat_importances = pd.Series(model.feature_importances_, index=x_train.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# Create dataframe with olny the best features
x_train = x_train[['HBA_07_ARC', 'HBA_07_HBA', 'WBN_EN_L_0.50', 'WBN_LP_H_0.50', 'WBN_GC_H_1.00']]

x_test = x_test[['HBA_07_ARC', 'HBA_07_HBA', 'WBN_EN_L_0.50', 'WBN_LP_H_0.50', 'WBN_GC_H_1.00']]

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras import optimizers
from keras import layers


model = Sequential()
model.add(Dense(64, input_dim=5, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

opt = optimizers.nadam(lr=.00001)

model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train,
          epochs=100,
          batch_size=128)
# Out:
# Epoch 1/100
# 76/76 [==============================] - 0s 164us/step - loss: 0.7015 - acc: 0.5263
# Epoch 2/100
# 76/76 [==============================] - 0s 179us/step - loss: 0.7021 - acc: 0.5263
# Epoch 3/100
# 76/76 [==============================] - 0s 184us/step - loss: 0.7097 - acc: 0.5132
# Epoch 4/100
# 76/76 [==============================] - 0s 96us/step - loss: 0.7385 - acc: 0.3684
# Epoch 5/100
# 76/76 [==============================] - 0s 140us/step - loss: 0.7320 - acc: 0.4474
# Epoch 6/100
# 76/76 [==============================] - 0s 134us/step - loss: 0.7236 - acc: 0.4737
# Epoch 7/100
# 76/76 [==============================] - 0s 115us/step - loss: 0.7438 - acc: 0.3947
# Epoch 8/100
# 76/76 [==============================] - 0s 123us/step - loss: 0.7347 - acc: 0.4079
# Epoch 9/100
# 76/76 [==============================] - 0s 142us/step - loss: 0.7218 - acc: 0.4342
# Epoch 10/100
# 76/76 [==============================] - 0s 94us/step - loss: 0.7128 - acc: 0.4868
# Epoch 11/100
# 76/76 [==============================] - 0s 137us/step - loss: 0.6939 - acc: 0.5000
# Epoch 12/100
# 76/76 [==============================] - 0s 86us/step - loss: 0.6986 - acc: 0.4737
# Epoch 13/100
# 76/76 [==============================] - 0s 116us/step - loss: 0.7269 - acc: 0.4605
# Epoch 14/100
# 76/76 [==============================] - 0s 80us/step - loss: 0.6841 - acc: 0.5526
# Epoch 15/100
# 76/76 [==============================] - 0s 115us/step - loss: 0.6757 - acc: 0.6184
# Epoch 16/100
# 76/76 [==============================] - 0s 125us/step - loss: 0.7188 - acc: 0.4342
# Epoch 17/100
# 76/76 [==============================] - 0s 102us/step - loss: 0.7144 - acc: 0.4474
# Epoch 18/100
# 76/76 [==============================] - 0s 105us/step - loss: 0.7147 - acc: 0.4737
# Epoch 19/100
# 76/76 [==============================] - 0s 107us/step - loss: 0.7223 - acc: 0.4605
# Epoch 20/100
# 76/76 [==============================] - 0s 138us/step - loss: 0.6671 - acc: 0.5921
# Epoch 21/100
# 76/76 [==============================] - 0s 102us/step - loss: 0.7139 - acc: 0.4474
# Epoch 22/100
# 76/76 [==============================] - 0s 116us/step - loss: 0.6647 - acc: 0.6316
# Epoch 23/100
# 76/76 [==============================] - 0s 130us/step - loss: 0.6927 - acc: 0.5132
# Epoch 24/100
# 76/76 [==============================] - 0s 131us/step - loss: 0.7008 - acc: 0.5132
# Epoch 25/100
# 76/76 [==============================] - 0s 133us/step - loss: 0.6851 - acc: 0.4737
# Epoch 26/100
# 76/76 [==============================] - 0s 113us/step - loss: 0.6811 - acc: 0.6184
# Epoch 27/100
# 76/76 [==============================] - 0s 138us/step - loss: 0.7204 - acc: 0.4342
# Epoch 28/100
# 76/76 [==============================] - 0s 134us/step - loss: 0.7067 - acc: 0.5658
# Epoch 29/100
# 76/76 [==============================] - 0s 112us/step - loss: 0.7205 - acc: 0.4211
# Epoch 30/100
# 76/76 [==============================] - 0s 133us/step - loss: 0.6712 - acc: 0.5263
# Epoch 31/100
# 76/76 [==============================] - 0s 122us/step - loss: 0.6961 - acc: 0.5000
# Epoch 32/100
# 76/76 [==============================] - 0s 137us/step - loss: 0.7287 - acc: 0.5000
# Epoch 33/100
# 76/76 [==============================] - 0s 132us/step - loss: 0.7000 - acc: 0.4868
# Epoch 34/100
# 76/76 [==============================] - 0s 141us/step - loss: 0.6897 - acc: 0.5263
# Epoch 35/100
# 76/76 [==============================] - 0s 145us/step - loss: 0.6905 - acc: 0.5395
# Epoch 36/100
# 76/76 [==============================] - 0s 134us/step - loss: 0.7078 - acc: 0.5000
# Epoch 37/100
# 76/76 [==============================] - 0s 121us/step - loss: 0.7020 - acc: 0.4737
# Epoch 38/100
# 76/76 [==============================] - 0s 126us/step - loss: 0.6866 - acc: 0.5921
# Epoch 39/100
# 76/76 [==============================] - 0s 128us/step - loss: 0.6913 - acc: 0.4868
# Epoch 40/100
# 76/76 [==============================] - 0s 114us/step - loss: 0.6941 - acc: 0.5526
# Epoch 41/100
# 76/76 [==============================] - 0s 131us/step - loss: 0.6526 - acc: 0.5789
# Epoch 42/100
# 76/76 [==============================] - 0s 128us/step - loss: 0.6708 - acc: 0.5789
# Epoch 43/100
# 76/76 [==============================] - 0s 107us/step - loss: 0.6882 - acc: 0.5658
# Epoch 44/100
# 76/76 [==============================] - 0s 136us/step - loss: 0.7273 - acc: 0.4211
# Epoch 45/100
# 76/76 [==============================] - 0s 145us/step - loss: 0.7142 - acc: 0.4737
# Epoch 46/100
# 76/76 [==============================] - 0s 106us/step - loss: 0.6757 - acc: 0.5395
# Epoch 47/100
# 76/76 [==============================] - 0s 128us/step - loss: 0.6612 - acc: 0.6447
# Epoch 48/100
# 76/76 [==============================] - 0s 111us/step - loss: 0.6806 - acc: 0.5526
# Epoch 49/100
# 76/76 [==============================] - 0s 151us/step - loss: 0.7157 - acc: 0.4737
# Epoch 50/100
# 76/76 [==============================] - 0s 137us/step - loss: 0.6942 - acc: 0.5000
# Epoch 51/100
# 76/76 [==============================] - 0s 104us/step - loss: 0.7175 - acc: 0.4605
# Epoch 52/100
# 76/76 [==============================] - 0s 136us/step - loss: 0.7086 - acc: 0.5000
# Epoch 53/100
# 76/76 [==============================] - 0s 119us/step - loss: 0.7249 - acc: 0.4211
# Epoch 54/100
# 76/76 [==============================] - 0s 112us/step - loss: 0.7250 - acc: 0.4868
# Epoch 55/100
# 76/76 [==============================] - 0s 137us/step - loss: 0.7106 - acc: 0.4868
# Epoch 56/100
# 76/76 [==============================] - 0s 159us/step - loss: 0.7077 - acc: 0.5132
# Epoch 57/100
# 76/76 [==============================] - 0s 104us/step - loss: 0.6762 - acc: 0.5658
# Epoch 58/100
# 76/76 [==============================] - 0s 138us/step - loss: 0.7042 - acc: 0.4868
# Epoch 59/100
# 76/76 [==============================] - 0s 99us/step - loss: 0.7179 - acc: 0.4737
# Epoch 60/100
# 76/76 [==============================] - 0s 146us/step - loss: 0.6513 - acc: 0.6184
# Epoch 61/100
# 76/76 [==============================] - 0s 143us/step - loss: 0.7095 - acc: 0.5263
# Epoch 62/100
# 76/76 [==============================] - 0s 126us/step - loss: 0.6890 - acc: 0.5263
# Epoch 63/100
# 76/76 [==============================] - 0s 107us/step - loss: 0.6833 - acc: 0.4737
# Epoch 64/100
# 76/76 [==============================] - 0s 116us/step - loss: 0.6984 - acc: 0.4868
# Epoch 65/100
# 76/76 [==============================] - 0s 130us/step - loss: 0.6869 - acc: 0.5789
# Epoch 66/100
# 76/76 [==============================] - 0s 149us/step - loss: 0.6960 - acc: 0.5263
# Epoch 67/100
# 76/76 [==============================] - 0s 144us/step - loss: 0.6932 - acc: 0.4868
# Epoch 68/100
# 76/76 [==============================] - 0s 110us/step - loss: 0.7070 - acc: 0.4868
# Epoch 69/100
# 76/76 [==============================] - 0s 131us/step - loss: 0.7181 - acc: 0.4605
# Epoch 70/100
# 76/76 [==============================] - 0s 148us/step - loss: 0.6827 - acc: 0.5132
# Epoch 71/100
# 76/76 [==============================] - 0s 139us/step - loss: 0.6827 - acc: 0.5395
# Epoch 72/100
# 76/76 [==============================] - 0s 120us/step - loss: 0.7174 - acc: 0.4474
# Epoch 73/100
# 76/76 [==============================] - 0s 148us/step - loss: 0.6862 - acc: 0.5263
# Epoch 74/100
# 76/76 [==============================] - 0s 148us/step - loss: 0.6823 - acc: 0.5263
# Epoch 75/100
# 76/76 [==============================] - 0s 112us/step - loss: 0.6891 - acc: 0.5658
# Epoch 76/100
# 76/76 [==============================] - 0s 147us/step - loss: 0.6893 - acc: 0.5263
# Epoch 77/100
# 76/76 [==============================] - 0s 145us/step - loss: 0.6987 - acc: 0.5132
# Epoch 78/100
# 76/76 [==============================] - 0s 152us/step - loss: 0.6963 - acc: 0.5263
# Epoch 79/100
# 76/76 [==============================] - 0s 139us/step - loss: 0.6664 - acc: 0.5789
# Epoch 80/100
# 76/76 [==============================] - 0s 185us/step - loss: 0.7030 - acc: 0.5263
# Epoch 81/100
# 76/76 [==============================] - 0s 168us/step - loss: 0.6934 - acc: 0.5526
# Epoch 82/100
# 76/76 [==============================] - 0s 130us/step - loss: 0.6943 - acc: 0.5789
# Epoch 83/100
# 76/76 [==============================] - 0s 149us/step - loss: 0.6678 - acc: 0.6184
# Epoch 84/100
# 76/76 [==============================] - 0s 151us/step - loss: 0.6972 - acc: 0.4868
# Epoch 85/100
# 76/76 [==============================] - 0s 182us/step - loss: 0.6516 - acc: 0.6579
# Epoch 86/100
# 76/76 [==============================] - 0s 162us/step - loss: 0.6905 - acc: 0.5526
# Epoch 87/100
# 76/76 [==============================] - 0s 126us/step - loss: 0.6536 - acc: 0.6579
# Epoch 88/100
# 76/76 [==============================] - 0s 141us/step - loss: 0.6586 - acc: 0.6184
# Epoch 89/100
# 76/76 [==============================] - 0s 81us/step - loss: 0.6717 - acc: 0.5526
# Epoch 90/100
# 76/76 [==============================] - 0s 134us/step - loss: 0.7008 - acc: 0.5395
# Epoch 91/100
# 76/76 [==============================] - 0s 75us/step - loss: 0.6657 - acc: 0.6316
# Epoch 92/100
# 76/76 [==============================] - 0s 126us/step - loss: 0.6841 - acc: 0.5263
# Epoch 93/100
# 76/76 [==============================] - 0s 74us/step - loss: 0.6800 - acc: 0.5921
# Epoch 94/100
# 76/76 [==============================] - 0s 127us/step - loss: 0.6577 - acc: 0.6053
# Epoch 95/100
# 76/76 [==============================] - 0s 75us/step - loss: 0.6431 - acc: 0.6447
# Epoch 96/100
# 76/76 [==============================] - 0s 137us/step - loss: 0.6670 - acc: 0.5921
# Epoch 97/100
# 76/76 [==============================] - 0s 80us/step - loss: 0.6894 - acc: 0.5789
# Epoch 98/100
# 76/76 [==============================] - 0s 114us/step - loss: 0.7030 - acc: 0.5658
# Epoch 99/100
# 76/76 [==============================] - 0s 65us/step - loss: 0.6807 - acc: 0.5658
# Epoch 100/100
# 76/76 [==============================] - 0s 119us/step - loss: 0.6854 - acc: 0.5526

# %%
score = model.evaluate(x_test, y_test, batch_size=128)
print('Score', score)
# Out:
# 18/18 [==============================] - 0s 8ms/step
# Score [0.6586897969245911, 0.7777777910232544]
